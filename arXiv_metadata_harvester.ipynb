# %% [markdown]
# # ArXiv metadata harvester

# %% [markdown]
# ## 1. Imports

# %%
import xmltodict          # to convert the raw metadata from xml format to dict
import pandas as pd       # final format of stored data
from sickle import Sickle # to retrieve data from the OAI arxiv interface

# %% [markdown]
# ## 2. Connection

# %%
#initialise an OAI interface
connection = Sickle('http://export.arxiv.org/oai2')

# %%
print('Getting papers...')
data = connection.ListRecords(**{'metadataPrefix': 'arXiv', 'from': '2007-01-01', 'until': '2019-06-01', 'ignore_deleted': True})
print('Papers retrieved.')
# Out:
# Getting papers...
# Papers retrieved.

# %% [markdown]
# ## 3. Export raw metadata in txt file

# %%
iters = 0
with open('arXiv_metadata_raw.txt','a+') as f:
    while True:
        try:
            f.write(data.next().raw)
            errors = 0
            iters +=1
            
            if iters % 10000 == 0:
                print('On iter', iters)
        
        except AttributeError:
            if errors >5:
                raise AttributeError('\nQUITTING: Too many sequential errors\n')
            else:
                print('\nERROR!\n')
                errors +=1
                
        except StopIteration:
            print('On iter', iters)
            print('\nDONE!')
            break
# Out:
# On iter 10000
# On iter 20000
# On iter 30000
# On iter 40000
# On iter 50000
# On iter 60000
# On iter 70000
# On iter 80000
# On iter 90000
# On iter 100000
# On iter 110000
# On iter 120000
# On iter 130000
# On iter 140000
#
# ERROR!
#
# On iter 150000
# On iter 160000
# On iter 170000
# On iter 180000
# On iter 190000
# On iter 200000
# On iter 210000
# On iter 220000
# On iter 230000
# On iter 240000
# On iter 250000
# On iter 260000
# On iter 270000
# On iter 280000
# On iter 290000
# On iter 300000
# On iter 310000
# On iter 320000
# On iter 330000
# On iter 340000
# On iter 350000
# On iter 360000
# On iter 370000
# On iter 380000
# On iter 390000
# On iter 400000
# On iter 410000
# On iter 420000
# On iter 430000
# On iter 440000
# On iter 450000
# On iter 460000
# On iter 470000
# On iter 480000
# On iter 490000
# On iter 500000
# On iter 510000
# On iter 520000
# On iter 530000
# On iter 540000
# On iter 550000
# On iter 560000
# On iter 570000
# On iter 580000
# On iter 590000
# On iter 600000
# On iter 610000
# On iter 620000
# On iter 630000
# On iter 640000
# On iter 650000
# On iter 660000
# On iter 670000
# On iter 680000
# On iter 690000
# On iter 700000
# On iter 710000
# On iter 720000
# On iter 730000
# On iter 740000
# On iter 750000
# On iter 760000
# On iter 770000
# On iter 780000
# On iter 790000
# On iter 800000
# On iter 810000
# On iter 820000
# On iter 830000
# On iter 840000
# On iter 850000
# On iter 860000
# On iter 870000
# On iter 880000
# On iter 890000
# On iter 900000
# On iter 910000
# On iter 920000
# On iter 930000
# On iter 940000
# On iter 950000
# On iter 960000
# On iter 970000
# On iter 980000
# On iter 990000
# On iter 1000000
# On iter 1010000
# On iter 1020000
# On iter 1030000
# On iter 1040000
# On iter 1050000
# On iter 1060000
# On iter 1070000
# On iter 1080000
# On iter 1090000
# On iter 1100000
# On iter 1110000
# On iter 1120000
# On iter 1130000
# On iter 1140000
# On iter 1150000
# On iter 1160000
# On iter 1170000
# On iter 1180000
# On iter 1190000
# On iter 1200000
# On iter 1210000
# On iter 1220000
# On iter 1230000
# On iter 1240000
# On iter 1250000
# On iter 1260000
# On iter 1270000
# On iter 1280000
# On iter 1290000
# On iter 1300000
# On iter 1310000
# On iter 1320000
# On iter 1330000
# On iter 1340000
# On iter 1350000
# On iter 1360000
# On iter 1370000
# On iter 1380000
# On iter 1390000
# On iter 1400000
# On iter 1410000
# On iter 1420000
# On iter 1430000
# On iter 1440000
# On iter 1450000
# On iter 1460000
# On iter 1470000
# On iter 1480000
# On iter 1490000
# On iter 1500000
# On iter 1510000
# On iter 1520000
# On iter 1530000
# On iter 1540000
# On iter 1540258
#
# DONE!

# %% [markdown]
# ## 4. Format raw data

# %%
raw_data = ''

with open('arXiv_metadata_raw.txt','r') as f:
    while True:
        data = f.read(100_000_000)
        if not data:
            break
        else:
            raw_data += data

# %%
def convert_dict(record_xml):
    record_dict = xmltodict.parse(record_xml, process_namespaces=False)['record']['metadata']['arXiv']
    
    record_dict['id'] = str(record_dict['id'])
    
    if not isinstance(record_dict['authors']['author'], list):
        authors = [record_dict['authors']['author']]
    else:
        authors = record_dict['authors']['author']
    
    authors = [(author['forenames'] + ' ' if 'forenames' in author.keys() else '') + author['keyname'] for author in authors]
        
    record_dict['authors'] = authors
    return record_dict

# %%
list_of_xml = raw_data.split('</record>')
list_of_xml = [_ + '</record>' for _ in list_of_xml]
list_of_dicts = [convert_dict(list_of_xml[i]) for i in range(1,len(list_of_xml)-1)]

# %%
df = pd.DataFrame(list_of_dicts)

# %% [markdown]
# ## 5. Export formatted data

# %%
df.head()
# Out:
#                         @xmlns                                 @xmlns:xsi  \
# 0  http://arxiv.org/OAI/arXiv/  http://www.w3.org/2001/XMLSchema-instance
# 1  http://arxiv.org/OAI/arXiv/  http://www.w3.org/2001/XMLSchema-instance
# 2  http://arxiv.org/OAI/arXiv/  http://www.w3.org/2001/XMLSchema-instance
# 3  http://arxiv.org/OAI/arXiv/  http://www.w3.org/2001/XMLSchema-instance
# 4  http://arxiv.org/OAI/arXiv/  http://www.w3.org/2001/XMLSchema-instance
#
#                                  @xsi:schemaLocation         id     created  \
# 0  http://arxiv.org/OAI/arXiv/ http://arxiv.org/O...  0704.0002  2007-03-30
# 1  http://arxiv.org/OAI/arXiv/ http://arxiv.org/O...  0704.0003  2007-04-01
# 2  http://arxiv.org/OAI/arXiv/ http://arxiv.org/O...  0704.0004  2007-03-30
# 3  http://arxiv.org/OAI/arXiv/ http://arxiv.org/O...  0704.0005  2007-04-02
# 4  http://arxiv.org/OAI/arXiv/ http://arxiv.org/O...  0704.0006  2007-03-31
#
#       updated                                  authors  \
# 0  2008-12-13           [Ileana Streinu, Louis Theran]
# 1  2008-01-12                            [Hongjun Pan]
# 2         NaN                           [David Callan]
# 3         NaN  [Wael Abu-Shammala, Alberto Torchinsky]
# 4         NaN                  [Y. H. Pong, C. K. Law]
#
#                                                title         categories  \
# 0           Sparsity-certifying Graph Decompositions      math.CO cs.CG
# 1  The evolution of the Earth-Moon system based o...     physics.gen-ph
# 2  A determinant of Stirling cycle numbers counts...            math.CO
# 3  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...    math.CA math.FA
# 4  Bosonic characters of atomic Cooper pairs acro...  cond-mat.mes-hall
#
#                                 comments                   msc-class  \
# 0  To appear in Graphs and Combinatorics  05C85; 05C70; 68R10; 05B35
# 1                    23 pages, 3 figures                         NaN
# 2                               11 pages                       05A15
# 3                                    NaN                42B30, 42B35
# 4    6 pages, 4 figures, accepted by PRA                         NaN
#
#                                              license  \
# 0  http://arxiv.org/licenses/nonexclusive-distrib...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             abstract  \
# 0  We describe a new algorithm, the $(k,\ell)$-pe...
# 1  The evolution of Earth-Moon system is describe...
# 2  We show that a determinant of Stirling cycle n...
# 3  In this paper we show how to compute the $\Lam...
# 4  We study the two-particle wave function of pai...
#
#                                  journal-ref                         doi  \
# 0                                        NaN                         NaN
# 1                                        NaN                         NaN
# 2                                        NaN                         NaN
# 3  Illinois J. Math. 52 (2008) no.2, 681-689                         NaN
# 4                                        NaN  10.1103/PhysRevA.75.043613
#
#   report-no acm-class proxy
# 0       NaN       NaN   NaN
# 1       NaN       NaN   NaN
# 2       NaN       NaN   NaN
# 3       NaN       NaN   NaN
# 4       NaN       NaN   NaN

# %%
df = df.drop(columns = ['@xmlns', '@xmlns:xsi', '@xsi:schemaLocation'])

# %%
df.to_csv('arXiv_metadata_formatted.csv')
